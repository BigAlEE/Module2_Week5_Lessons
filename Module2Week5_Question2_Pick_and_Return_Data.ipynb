# %% [markdown]
# ### How to get and use an API with API key
# - RTFM (Read The Documentation https://coinmarketcap.com/api/documentation/v1/#)
# - Import modules and API key
# - Test a basic request
# - Build up a class so we can easily make the REST API calls

# %%
# API Key for Coin Market Cap API

API_Key = "cb714f74-27cc-43d7-99b9-28dbe520ec51"

# %%
import pandas as pd
import requests
import api_key

# %%
url = "https://pro-api.coinmarketcap.com/v1/cryptocurrency/map"
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': api_key.API_KEY,
}

response = requests.get(url, headers = headers)

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'status': {'timestamp': '2025-05-18T19:43:29.842Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 341,
#   'credit_count': 1,
#   'notice': None},
#  'data': [{'id': 1,
#    'rank': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'slug': 'bitcoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2010-07-13T00:05:00.000Z',
#    'last_historical_data': '2025-05-18T19:30:00.000Z',
#    'platform': None},
#   {'id': 2,
#    'rank': 21,
#    'name': 'Litecoin',
#    'symbol': 'LTC',
#    'slug': 'litecoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-04-28T18:45:00.000Z',
#    'last_historical_data': '2025-05-18T19:30:00.000Z',
#    'platform': None},
#   {'id': 3,
#    'rank': 939,
#    'name': 'Namecoin',
#    'symbol': 'NMC',
#    'slug': 'namecoin',
#    'is_active': 1,
#    'status': 1,
#    'first_historical_data': '2013-04-28T18:45:00.000Z',
#    'last_historical_data': '2025-05-18T19:30:00.000Z',
# ...

# %%
from pprint import pprint as pp

# %%
df_coin = pd.DataFrame(response)

df_coin.head(10)
# Out:
#                                                    0
# 0  b'{"status":{"timestamp":"2025-05-18T19:43:29....
# 1  b'll},"data":[{"id":1,"rank":1,"name":"Bitcoin...
# 2  b'2010-07-13T00:05:00.000Z","last_historical_d...
# 3  b',"symbol":"LTC","slug":"litecoin","is_active...
# 4  b'ata":"2025-05-18T19:30:00.000Z","platform":n...
# 5  b'e":1,"status":1,"first_historical_data":"201...
# 6  b'null},{"id":4,"rank":6464,"name":"Terracoin"...
# 7  b'"2013-04-28T18:45:00.000Z","last_historical_...
# 8  b'in","symbol":"PPC","slug":"peercoin","is_act...
# 9  b'l_data":"2025-05-18T19:30:00.000Z","platform...

# %%
df_coin.tail(10)
# Out:
#                                                        0
# 25173  b'last_historical_data":"2025-05-18T19:35:00.0...
# 25174  b'dress":"0x06FB462769254aD36FC9877F0b2C301455...
# 25175  b'active":1,"status":1,"first_historical_data"...
# 25176  b'orm":{"id":199,"name":"Base","symbol":"TBA",...
# 25177  b'6536,"rank":3186,"name":"Project MIRAI","sym...
# 25178  b':"2025-05-17T08:35:00.000Z","last_historical...
# 25179  b',"slug":"solana","token_address":"5evN2exivZ...
# 25180  b':"RIZE","slug":"rize","is_active":1,"status"...
# 25181  b'5-18T19:35:00.000Z","platform":{"id":199,"na...
# 25182                            b'587c427C7C93583"}}]}'

# %%
df_coin
# Out:
#                                                        0
# 0      b'{"status":{"timestamp":"2025-05-18T19:43:29....
# 1      b'll},"data":[{"id":1,"rank":1,"name":"Bitcoin...
# 2      b'2010-07-13T00:05:00.000Z","last_historical_d...
# 3      b',"symbol":"LTC","slug":"litecoin","is_active...
# 4      b'ata":"2025-05-18T19:30:00.000Z","platform":n...
# ...                                                  ...
# 25178  b':"2025-05-17T08:35:00.000Z","last_historical...
# 25179  b',"slug":"solana","token_address":"5evN2exivZ...
# 25180  b':"RIZE","slug":"rize","is_active":1,"status"...
# 25181  b'5-18T19:35:00.000Z","platform":{"id":199,"na...
# 25182                            b'587c427C7C93583"}}]}'
#
# [25183 rows x 1 columns]
